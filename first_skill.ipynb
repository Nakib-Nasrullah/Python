# %% [markdown]
# <a href="https://colab.research.google.com/github/Nakib-Nasrullah/Python/blob/main/first_skill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **welcome program**

# %%
print("Welcome to Data science")
# Out:
# Welcome to Data science

# %% [markdown]
# 2nd **Section**

# %% [markdown]
# # New Section
