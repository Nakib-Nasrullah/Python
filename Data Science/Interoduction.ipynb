# %% [markdown]
# <a href="https://colab.research.google.com/github/Nakib-Nasrullah/Python/blob/main/Data%20Science/Interoduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello word! This is Nakib.")
# Out:
# Hello word! This is Nakib.

# %%
23 + 45
# Out:
# 68

# %% [markdown]
# # **cahpter 1**

# %% [markdown]
# ## **Sub Chapter 1**
